# %%
jobs
# Out:
# ['1) Role : Content Specialist | Company : Gibby | Salary :  IDR 6.000.000 - 10.000.000 | Link : https://glints.com/id/opportunities/jobs/content-specialist/d291a7f8-8944-4489-902b-ef6aba92a84e',
#  '2) Role : Content specialist lead | Company : Base | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/content-specialist-lead/04ca8c9a-f119-46d0-af1d-e9cf5f1def2b',
#  '3) Role : Digital Content Creator  | Company : PT Organika Alam Semesta | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/digital-content-creator/c56a11c9-fd10-4471-bcf2-1d9ad3d071fa',
#  '4) Role : Digital Marketing Specialist | Company : Pt Cibes Lift Indonesia | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/digital-marketing-specialist/3d291123-53db-4403-8a8c-fa8e3e7bc451',
#  '5) Role : Digital Marketing Specialist | Company : Get | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/digital-marketing-specialist/2a1881f6-a2fc-45b7-87a7-dd7687c793dd',
#  '6) Role : Digital Marketing Specialist | Company : Machtwatch | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/digital-marketing-specialist/34274581-4ec7-494e-8e12-8d8c0b925377',
#  '7) Role : Digital Marketing Specialist | Company : Ubiklan | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/digital-marketing-specialist/ef3a3160-2dbd-4a59-b888-e7c181e9dd52',
#  '8) Role : Digital Marketing Intern - Content Writing | Company : Bagidata | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/digital-marketing-intern-content-writing/683f5ac5-67b6-4487-8fde-5acc437d2146',
#  '9) Role : Content Creator | Company : Medikpro Aesthetics & Laser Clinic | Salary :  IDR 5.000.000 - 7.000.000 | Link : https://glints.com/id/opportunities/jobs/content-creator/7a96ea14-8b16-4974-a038-6ef433d12e56',
#  '10) Role : Content Strategist | Company : Alpha Class | Salary :  IDR 4.500.000 - 7.000.000 | Link : https://glints.com/id/opportunities/jobs/content-strategist/38b45c09-6a2a-4c0f-9cb7-951b626c0897',
#  '11) Role : Content Writer | Company : Marketz.id | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/content-writer/1d591a23-f579-406e-882b-5e3c8002dbb2',
#  '12) Role : Server Specialist | Company : Home Credit Indonesia | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/server-specialist/47b8cab8-adab-4a3c-a38e-36fd85772c38',
#  '13) Role : Insurance Specialist | Company : GPS United | Salary :  IDR 7.500.000 - 10.000.000 | Link : https://glints.com/id/opportunities/jobs/insurance-specialist/aa73e4b9-e5a1-4503-8bda-48a45c115852',
#  '14) Role : Content Writer | Company : Hello Kreasi Indonesia | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/content-writer/7625751d-0ef0-4955-846b-f0ecdaa40db1',
#  '15) Role : Marketing Specialist | Company : PT Kreasi Persada Abadi | Salary :  IDR 5.000.000 - 8.000.000 | Link : https://glints.com/id/opportunities/jobs/marketing-specialist/30cfc83b-0f8a-4330-aab3-22f0a20fc452',
#  '16) Role : Digital Marketing and Community Specialist (Internship or Full time) | Company : CV Pemindo Multi Sukses | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/digital-marketing-and-community-specialist-internship-or-full-time/6dcb908b-22c4-4b7d-b34d-bd9fff1ab2ae',
#  '17) Role : Copy/Content Writer | Company : PT Sinergi Rezeki Ananta | Salary :  IDR 3.000.000 - 4.000.000 | Link : https://glints.com/id/opportunities/jobs/copy-content-writer/3d65b7bd-c184-4206-a413-914595d176a4',
#  '18) Role : Sr. Content Writer | Company : Kriya People | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/sr-content-writer/e397f05e-c8e0-4261-a76f-8e5fed121ff6',
#  '19) Role : Content Development Team | Company : Confidential - 002 | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs/content-development-team/394026d9-6133-4881-b823-45c32b3cda22',
#  '20) Role : SEO Specialist | Company : Gibby | Salary : Unknown | Link : https://glints.com/id/opportunities/jobs
#  '120) Role : BD E-commerce | Company : PT Mobile Tunai Indonesia (KAS-E) | Salary :  IDR 1.234 - 5.678 | Link : https://glints.com/id/opportunities/jobs/bd-e-commerce/5aeb7e05-c9f3-4864-8c7b-9847f49116e4']

# %%
boxes[0].find_all("div", class_ = "JobCardsc__JobcardContainer-sc-1f9hdu8-0 gHylFc CompactOpportunityCardsc__CompactJobCardWrapper-sc-1xtox99-0 ldEJrJ compact_job_card")
# Out:
# 120

# %%
import requests, time, telebot
from bs4 import BeautifulSoup
from selenium import webdriver

urlDCS = "https://glints.com/id/opportunities/jobs/explore?keywords=digital%20content%20specialist&sortBy=relevancy&countries=ID&cities=28904"
urlSMA = "https://glints.com/id/opportunities/jobs/explore?sortBy=relevancy&countries=ID&cities=28904&keywords=social%20media%20associate"
urlPRO = "https://glints.com/id/opportunities/jobs/explore?sortBy=relevancy&countries=ID&cities=28904&keywords=producer"

# def process_html(url):
#     global jobs
    
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(chrome_options = options, executable_path =  r"C:\Users\Ezra\Desktop\chromedriver.exe")
driver.get(urlDCS)
time.sleep(3)

height = 4000
for scroll in range(0,3):
    driver.execute_script(f"window.scrollTo(0, {height})")
    time.sleep(5)
    height += 4000

page = driver.execute_script('return document.body.innerHTML')
body = BeautifulSoup(''.join(page), 'html.parser')
time.sleep(5)
driver.close()

boxes = body.find_all("div", class_ = "CompactJobCardListsc__JobCardListContainer-sc-1jkgvrs-0 jRweRm")
boxes = boxes[0].find_all("div", class_ = "JobCardsc__JobcardContainer-sc-1f9hdu8-0 gHylFc CompactOpportunityCardsc__CompactJobCardWrapper-sc-1xtox99-0 ldEJrJ compact_job_card")

jobs = []
for box, index in zip(boxes, range(1, len(boxes) + 1)):
    first_row = box.find("a", class_ = "CompactOpportunityCardsc__JobTitleLink-sc-1xtox99-8 hAEIfu gtm-job-card-job-title")

    role = first_row.text
    company = box.find("a", class_ = "CompactOpportunityCardsc__CompanyLink-sc-1xtox99-9 gOQwrG").text
    salary = box.find_all("p", class_ = "CompactOpportunityCardsc__OpportunityInfo-sc-1xtox99-13 bhlpvS")[1].text
    if  salary == "":
        salary = "Unknown"

    else:
        salary = salary.replace("\xa0", " ")
    link = "https://glints.com" + first_row["href"]

    jobs.append(f"{index}) Role : {role} | Company : {company} | Salary : {salary} | Link : {link}")

# token='810975399:AAGWhxFmw_Cs96ZVZG3PeM9gTlz2nLTDpaM'
# bot = telebot.TeleBot(token)

# @bot.message_handler(commands = ['start'])
# def send_welcome(message):
#     bot.reply_to(message, "These are two commands you can use: \n\n /glintsDCS: Provides all 'Digital Content Specialist' jobs query results (Location : Jakarta) in Glints \n\n /glintsSMA: Provides all 'Social Media Associate' jobs query results (Location : Jakarta) in Glints \n\n /glintsPRO: Provides all 'Producer' jobs query results (Location : Jakarta) in Glints")

# @bot.message_handler(commands = ['glintsDCS'])
# def glintsDCS(message):
#     bot.reply_to(message, "Please wait")
    
#     process_html(urlDCS)
    
#     start = 0
#     end = 15
#     for reply in range(int(len(jobs) / 15)):
#         bot.reply_to(message, " \n\n".join(jobs[start:end]))
        
#         start = end
#         end += 15
    
# @bot.message_handler(commands = ['glintsSMA'])
# def glintsSMA(message):
#     bot.reply_to(message, "Please wait")
    
#     process_html(urlSMA)
    
#     start = 0
#     end = 15
#     for reply in range(int(len(jobs) / 15)):
#         bot.reply_to(message, " \n\n".join(jobs[start:end]))
        
#         start = end
#         end += 15

# @bot.message_handler(commands = ['glintsPRO'])
# def glintsDCS(message):
#     bot.reply_to(message, "Please wait")
    
#     process_html(urlPRO)
    
#     start = 0
#     end = 15
#     for reply in range(int(len(jobs) / 15)):
#         bot.reply_to(message, " \n\n".join(jobs[start:end]))
        
#         start = end
#         end += 15

# while True:
#     print ("Is running...")
    
#     try:
#         bot.polling(none_stop = True)

#     except Exception:
#         time.sleep(5)
# Out:
# C:\Users\Ezra\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: use options instead of chrome_options
#   del sys.path[0]

# %%
import requests, time, telebot
from bs4 import BeautifulSoup
from selenium import webdriver

urlDA = "https://glints.com/id/opportunities/jobs/explore?countries=ID&keywords=data%20analyst&cities=28904"
urlDS = "https://glints.com/id/opportunities/jobs/explore?gclid=CjwKCAjwt-L2BRA_EiwAacX32Tli6k6uW386mz-DzemeU_ybC1VGcfkpTfEwsDIaTFIwZ3GrqC7IpRoCyZUQAvD_BwE&p=id%2Flowongan-kerja&keywords=data%20scientist&countries=ID&cities=28904"

def process_html(url):
    global jobs
    
    options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(chrome_options = options, executable_path =  r"C:\Users\Ezra\Documents\Python Scripts\Training\Bot\chromedriver.exe")
    driver.get(url)
    time.sleep(3)

    height = 4000
    for scroll in range(0,3):
        driver.execute_script(f"window.scrollTo(0, {height})")
        time.sleep(5)
        height += 4000

    page = driver.execute_script('return document.body.innerHTML')
    body = BeautifulSoup(''.join(page), 'html.parser')
    time.sleep(5)
    driver.close()
    
    boxes = list(body.find_all("div", class_ = "job-card-info CompactOpportunityCardsc__CompactJobCardInfo-sc-1xtox99-7 kTDInJ"))

    jobs = []
    for box, index in zip(boxes, range(1, len(boxes) + 1)):
        first_row = box.find("a", class_ = "gtm-job-card-job-title CompactOpportunityCardsc__JobTitleLink-sc-1xtox99-8 hAEIfu")

        role = first_row.text
        company = box.find("a", class_ = "CompactOpportunityCardsc__CompanyLink-sc-1xtox99-9 gOQwrG").text
        salary = box.find_all("p", class_ = "CompactOpportunityCardsc__OpportunityInfo-sc-1xtox99-13 bhlpvS")[1].text
        if  salary == "":
            salary = "Unknown"
            
        else:
            salary = salary.replace("\xa0", " ")
        link = "https://glints.com" + first_row["href"]

        jobs.append(f"{index}) Role : {role} | Company : {company} | Salary : {salary} | Link : {link}")

token='810975399:AAGWhxFmw_Cs96ZVZG3PeM9gTlz2nLTDpaM'
bot = telebot.TeleBot(token)

@bot.message_handler(commands = ['start'])
def send_welcome(message):
    bot.reply_to(message, "These are two commands you can use: \n\n /glints_DA : Provides all 'Data Analyst' jobs query results (Location : Jakarta and Indonesia) in Glints \n\n /glints_DS : Provides all 'Data Science' jobs query results (Location : Jakarta and Indonesia) in Glints")

@bot.message_handler(commands = ['glints_DA'])
def glints_data_analyst(message):   
    print("Loading...")
    
    bot.reply_to(message, "Please wait")
    
    process_html(urlDA)
    
    start = 0
    end = 15
#     for reply in range(int(len(jobs) / 15)):
#         bot.reply_to(message, " \n\n".join(jobs[start:end]))
        
#         start = end
#         end += 15
    bot.reply_to(message, "success")
    
@bot.message_handler(commands = ['glints_DS'])
def glints_data_scientist(message):       
    print("Loading...")
    
    bot.reply_to(message, "Please wait")
    
    process_html(urlDS)
    
    start = 0
    end = 15
    for reply in range(int(len(jobs) / 15)):
        bot.reply_to(message, " \n\n".join(jobs[start:end]))
        
        start = end
        end += 15

while True:
    print ("Is running...")
    
    try:
        bot.polling(none_stop = True)

    except Exception:
        time.sleep(5)

# %%
import requests, time, telebot
from bs4 import BeautifulSoup
from selenium import webdriver

urlDCS = "https://glints.com/id/opportunities/jobs/explore?keywords=digital%20content%20specialist&sortBy=relevancy&countries=ID&cities=28904"
urlSMA = "https://glints.com/id/opportunities/jobs/explore?sortBy=relevancy&countries=ID&cities=28904&keywords=social%20media%20associate"
urlPRO = "https://glints.com/id/opportunities/jobs/explore?sortBy=relevancy&countries=ID&cities=28904&keywords=producer"

def process_html(url):
    global jobs
    
    options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(chrome_options = options, executable_path =  r"C:\Users\Ezra\Desktop\chromedriver.exe")
    driver.get(url)
    time.sleep(3)

    height = 4000
    for scroll in range(0,3):
        driver.execute_script(f"window.scrollTo(0, {height})")
        time.sleep(5)
        height += 4000

    page = driver.execute_script('return document.body.innerHTML')
    body = BeautifulSoup(''.join(page), 'html.parser')
    time.sleep(5)
    driver.close()
    
    boxes = list(body.find_all("div", class_ = "job-card-info CompactOpportunityCardsc__CompactJobCardInfo-sc-1xtox99-7 kTDInJ"))

    jobs = []
    for box, index in zip(boxes, range(1, len(boxes) + 1)):
        first_row = box.find("a", class_ = "gtm-job-card-job-title CompactOpportunityCardsc__JobTitleLink-sc-1xtox99-8 hAEIfu")

        role = first_row.text
        company = box.find("a", class_ = "CompactOpportunityCardsc__CompanyLink-sc-1xtox99-9 gOQwrG").text
        salary = box.find_all("p", class_ = "CompactOpportunityCardsc__OpportunityInfo-sc-1xtox99-13 bhlpvS")[1].text
        if  salary == "":
            salary = "Unknown"
            
        else:
            salary = salary.replace("\xa0", " ")
        link = "https://glints.com" + first_row["href"]

        jobs.append(f"{index}) Role : {role} | Company : {company} | Salary : {salary} | Link : {link}")

token='810975399:AAGWhxFmw_Cs96ZVZG3PeM9gTlz2nLTDpaM'
bot = telebot.TeleBot(token)

@bot.message_handler(commands = ['start'])
def send_welcome(message):
    bot.reply_to(message, "These are two commands you can use: \n\n /glintsDCS: Provides all 'Digital Content Specialist' jobs query results (Location : Jakarta) in Glints \n\n /glintsSMA: Provides all 'Social Media Associate' jobs query results (Location : Jakarta) in Glints \n\n /glintsPRO: Provides all 'Producer' jobs query results (Location : Jakarta) in Glints")

@bot.message_handler(commands = ['glintsDCS'])
def glintsDCS(message):
    bot.reply_to(message, "Please wait")
    
    process_html(urlDCS)
    
    start = 0
    end = 15
    for reply in range(int(len(jobs) / 15)):
        bot.reply_to(message, " \n\n".join(jobs[start:end]))
        
        start = end
        end += 15
    
@bot.message_handler(commands = ['glintsSMA'])
def glintsSMA(message):
    bot.reply_to(message, "Please wait")
    
    process_html(urlSMA)
    
    start = 0
    end = 15
    for reply in range(int(len(jobs) / 15)):
        bot.reply_to(message, " \n\n".join(jobs[start:end]))
        
        start = end
        end += 15

@bot.message_handler(commands = ['glintsPRO'])
def glintsDCS(message):
    bot.reply_to(message, "Please wait")
    
    process_html(urlPRO)
    
    start = 0
    end = 15
    for reply in range(int(len(jobs) / 15)):
        bot.reply_to(message, " \n\n".join(jobs[start:end]))
        
        start = end
        end += 15

while True:
    print ("Is running...")
    
    try:
        bot.polling(none_stop = True)

    except Exception:
        time.sleep(5)
